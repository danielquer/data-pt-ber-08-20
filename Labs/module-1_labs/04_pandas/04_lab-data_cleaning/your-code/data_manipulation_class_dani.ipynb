# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../vehicles.csv')
df.head()


df.columns
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# Renaming columns

# %%
df = df.rename(columns={'Make':'Manufacturer'})

# %%
df.rename(columns={'Manufacturer':'Make','Engine Displacement':'Displacement'}, inplace = True)

# %%
df.rename(columns={'Make':'Manufacturer','Displacement':'Engine Displacement'}, inplace = True)

# %%
df
# Out:
#            Manufacturer                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# Filtering data

# %%
df[df['Manufacturer'] == 'Ford']
# Out:
#       Manufacturer               Model  Year  Engine Displacement  Cylinders  \
# 11440         Ford        Aerostar Van  1986                  2.3        4.0
# 11441         Ford        Aerostar Van  1986                  2.3        4.0
# 11442         Ford        Aerostar Van  1986                  2.8        6.0
# 11443         Ford        Aerostar Van  1986                  2.8        6.0
# 11444         Ford        Aerostar Van  1986                  3.0        6.0
# ...            ...                 ...   ...                  ...        ...
# 14381         Ford  Windstar FWD Wagon  2000                  3.0        6.0
# 14382         Ford  Windstar FWD Wagon  2000                  3.8        6.0
# 14383         Ford  Windstar FWD Wagon  2001                  3.8        6.0
# 14384         Ford  Windstar FWD Wagon  2002                  3.8        6.0
# 14385         Ford  Windstar FWD Wagon  2003                  3.8        6.0
#
# ...

# %%
df_ford = df[df['Manufacturer'] == 'Ford']
df_ford
# Out:
#       Manufacturer               Model  Year  Engine Displacement  Cylinders  \
# 11440         Ford        Aerostar Van  1986                  2.3        4.0
# 11441         Ford        Aerostar Van  1986                  2.3        4.0
# 11442         Ford        Aerostar Van  1986                  2.8        6.0
# 11443         Ford        Aerostar Van  1986                  2.8        6.0
# 11444         Ford        Aerostar Van  1986                  3.0        6.0
# ...            ...                 ...   ...                  ...        ...
# 14381         Ford  Windstar FWD Wagon  2000                  3.0        6.0
# 14382         Ford  Windstar FWD Wagon  2000                  3.8        6.0
# 14383         Ford  Windstar FWD Wagon  2001                  3.8        6.0
# 14384         Ford  Windstar FWD Wagon  2002                  3.8        6.0
# 14385         Ford  Windstar FWD Wagon  2003                  3.8        6.0
#
# ...

# %%
df_ford_1986 = df[(df['Manufacturer'] == 'Ford') & (df['Year'] == 1986)]
df_ford_1986
# Out:
#       Manufacturer         Model  Year  Engine Displacement  Cylinders  \
# 11440         Ford  Aerostar Van  1986                  2.3        4.0
# 11441         Ford  Aerostar Van  1986                  2.3        4.0
# 11442         Ford  Aerostar Van  1986                  2.8        6.0
# 11443         Ford  Aerostar Van  1986                  2.8        6.0
# 11444         Ford  Aerostar Van  1986                  3.0        6.0
# ...            ...           ...   ...                  ...        ...
# 14270         Ford   Thunderbird  1986                  2.3        4.0
# 14271         Ford   Thunderbird  1986                  2.3        4.0
# 14272         Ford   Thunderbird  1986                  3.8        6.0
# 14273         Ford   Thunderbird  1986                  3.8        6.0
# 14274         Ford   Thunderbird  1986                  5.0        8.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# ...

# %%
df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
df['Hello'] = 'Hello'
df.head()
# Out:
#        Manufacturer                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
from datetime import datetime 
# Current date time in local system print(datetime.now())
df['Age'] = datetime.now().year - df['Year']

# %%
df['2020'] = df['Age'] + df['Year']

# %%
df
# Out:
#            Manufacturer                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# Drop columns

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'Hello', 'Age', '2020'],
#       dtype='object')

# %%
df.drop('2020', axis=1, inplace = True)

# %%
df.drop(['Highway MPG','City MPG'], axis=1, inplace = True)

# %% [markdown]
# Applying Functions to columns

# %%
df['Fuel Barrels/Year'].sum()
# Out:
# 633080.763419701

# %%
df.sum()
# Out:
# Manufacturer               AM GeneralAM GeneralAM GeneralAM GeneralASC In...
# Model                      DJ Po Vehicle 2WDFJ8c Post OfficePost Office D...
# Year                                                                71929756
# Engine Displacement                                                   120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdAutomatic 3-spdA...
# Drivetrain                 2-Wheel Drive2-Wheel DriveRear-Wheel DriveRear...
# Vehicle Class              Special Purpose Vehicle 2WDSpecial Purpose Veh...
# Fuel Type                  RegularRegularRegularRegularPremiumRegularRegu...
# Fuel Barrels/Year                                                     633081
# Combined MPG                                                          716499
# CO2 Emission Grams/Mile                                          1.70886e+07
# ...

# %%
maxyear = df['Year'].max()
maxcitympg = df['Combined MPG'].max()
print(f'In {maxyear} there haven\'t been more than {maxcitympg} miles per gallon.')
# Out:
# In 2017 there haven't been more than 56 miles per gallon.

# %% [markdown]
# Merging Dataframes

# %%
df = df.sort_values(by = ['Year','Combined MPG'], ascending = False)

# %%
df.nlargest(3,'Year')
# Out:
#       Manufacturer          Model  Year  Engine Displacement  Cylinders  \
# 33280       Toyota      Prius Eco  2017                  1.8        4.0
# 33278       Toyota          Prius  2017                  1.8        4.0
# 17058        Honda  Accord Hybrid  2017                  2.0        4.0
#
#                            Transmission         Drivetrain Vehicle Class  \
# 33280  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 33278  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 17058  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
#
#       Fuel Type  Fuel Barrels/Year  Combined MPG  CO2 Emission Grams/Mile  \
# 33280   Regular           5.885893            56                    158.0
# 33278   Regular           6.338654            52                    171.0
# 17058   Regular           6.866875            48                    183.0
#
#        Fuel Cost/Year  Hello  Age
# 33280             600  Hello    3
# ...

# %%
df = df.sort_index()
df
# Out:
#            Manufacturer                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
df['Manufacturer'].apply(str.upper)
# Out:
# 0              AM GENERAL
# 1              AM GENERAL
# 2              AM GENERAL
# 3              AM GENERAL
# 4        ASC INCORPORATED
#                ...
# 35947               SMART
# 35948               SMART
# 35949               SMART
# 35950               SMART
# 35951               SMART
# Name: Manufacturer, Length: 35952, dtype: object

# %%
a_to_b = lambda x: x.replace('a','b')


df[['Manufacturer','Transmission']].apply(a_to_b)
# Out:
#            Manufacturer     Transmission
# 0            AM General  Automatic 3-spd
# 1            AM General  Automatic 3-spd
# 2            AM General  Automatic 3-spd
# 3            AM General  Automatic 3-spd
# 4      ASC Incorporated  Automatic 4-spd
# ...                 ...              ...
# 35947             smart        Auto(AM5)
# 35948             smart        Auto(AM5)
# 35949             smart        Auto(AM5)
# 35950             smart        Auto(AM6)
# 35951             smart     Manual 5-spd
#
# [35952 rows x 2 columns]

# %%
uncapitalise = lambda x: x.lower()

df['Manufacturer'].apply(uncapitalise)
# Out:
# 0              am general
# 1              am general
# 2              am general
# 3              am general
# 4        asc incorporated
#                ...
# 35947               smart
# 35948               smart
# 35949               smart
# 35950               smart
# 35951               smart
# Name: Manufacturer, Length: 35952, dtype: object

# %% [markdown]
# Dataframe Aggregation using groupby

# %%
df.groupby(['Drivetrain','Manufacturer'])['Cylinders'].mean()
# Out:
# Drivetrain        Manufacturer
# 2-Wheel Drive     AM General               5.000000
#                   Buick                    7.333333
#                   Chevrolet                6.540000
#                   Chrysler                 6.000000
#                   Dodge                    6.338028
#                                              ...
# Rear-Wheel Drive  Vixen Motor Company      6.000000
#                   Volkswagen               4.000000
#                   Volvo                    4.345946
#                   Wallace Environmental    7.870968
#                   smart                    3.000000
# Name: Cylinders, Length: 298, dtype: float64

# %%
df.groupby(['Drivetrain'])[['Cylinders','Fuel Cost/Year']].agg(['mean','min','max'])
# Out:
#                            Cylinders            Fuel Cost/Year
#                                 mean  min   max           mean   min   max
# Drivetrain
# 2-Wheel Drive               6.156028  4.0   8.0    2115.011820  1150  3700
# 2-Wheel Drive, Front        4.000000  4.0   4.0    1450.000000  1450  1450
# 4-Wheel Drive               6.364839  4.0  12.0    1971.644612  1150  3400
# 4-Wheel or All-Wheel Drive  6.143626  3.0  16.0    2165.023835  1200  4050
# All-Wheel Drive             5.980383  3.0  16.0    1863.217263  1000  4050
# Front-Wheel Drive           4.608172  3.0   8.0    1503.131708   600  2700
# Part-time 4-Wheel Drive     7.113924  4.0  12.0    2131.645570  1650  3700
# Rear-Wheel Drive            6.643486  2.0  12.0    2140.397611  1000  5800

# %%
df.groupby(['Fuel Type'])[['Cylinders','City MPG']].agg(['mean','min','max'])
# Out:
#                             Cylinders              City MPG
#                                  mean  min   max       mean min max
# Fuel Type
# CNG                          6.500000  4.0   8.0  15.966667   8  27
# Diesel                       6.225027  4.0  10.0  21.173436  13  38
# Gasoline or E85              6.974059  4.0   8.0  15.347280  10  28
# Gasoline or natural gas      6.800000  4.0   8.0  13.700000  10  21
# Gasoline or propane          8.000000  8.0   8.0  12.000000  11  13
# Midgrade                     7.864865  6.0   8.0  14.851351  13  21
# Premium                      6.365286  2.0  16.0  16.793166   6  42
# Premium Gas or Electricity   4.235294  2.0   8.0  30.705882  20  41
# Premium and Electricity      4.850000  3.0   8.0  24.900000  16  37
# Premium or E85               6.892562  4.0  12.0  17.305785  11  24
# Regular                      5.420952  2.0  12.0  17.970195   7  58
# Regular Gas and Electricity  4.000000  4.0   4.0  43.125000  38  51
# ...
