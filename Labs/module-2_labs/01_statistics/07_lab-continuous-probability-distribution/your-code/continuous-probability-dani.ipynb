# %% [markdown]
# ## Continous Probability Distributions

# %% [markdown]
# To calculate probability of continuous variables, we compute the total area under the distribution curve of the sample space. At a given point of the curve, the area is approximately zero.
# We can convert a continuous distribution to descrete distribution by using multiple bins where each bin represents the probability value of a certain range.

# %%
# Probability Density Function
# P(a <= x <= b) = integral (from a to b) of derivative of function of x

# %%
# Cumulative Distribution Function
# F(a) = P(X E (-Infinite, a]) = integral (from -infinite to a) of derivative of function of x

# %%
# Continuous Uniform Distribution. Example of one
import numpy as np
from matplotlib import pyplot as plt
np.random.random()
# Out:
# 0.031163702619426026

# %%
from scipy.stats import uniform

# %%
cuni = uniform()
X = cuni.rvs(size=100)

plt.hist(X)
# Out:
# (array([10.,  9., 10.,  6., 10., 14., 12., 11.,  8., 10.]),
#  array([7.83618196e-04, 1.00238270e-01, 1.99692923e-01, 2.99147575e-01,
#         3.98602227e-01, 4.98056879e-01, 5.97511531e-01, 6.96966183e-01,
#         7.96420835e-01, 8.95875488e-01, 9.95330140e-01]),
#  <a list of 10 Patch objects>)

# %%
numrange = np.linspace(-0.1,1.1,100)

# %%
plt.plot(numrange,cuni.pdf(numrange))

# %%
plt.plot(numrange,cuni.cdf(numrange))

# %%
cuni = uniform(0,10)
numrange = np.linspace(-1,11,100)
plt.plot(numrange,cuni.pdf(numrange))

# %% [markdown]
# ## Normal distribution

# %%
from scipy.stats import norm
mean = 0
std = 1
normal = norm(mean,std)

# %%
numrange = np.linspace(-4,4,100)
plt.plot(numrange,normal.pdf(numrange))

# %%
numrange = np.linspace(-4,4,100)
plt.plot(numrange,normal.cdf(numrange))

# %%
X = normal.rvs(size = 10000)
plt.hist(X,bins=100)
plt.show()

# %%
# Skewness is a measure of symmetry. 
# left skewed - median < mean. Some outliers on the beginning are dragging the mean down compared to the median. E.g. Age of deaths in western societies.
# right skewed - mean > median. Some outliers on the end are dragging the mean up compared to the median. E.g. Income, poisson distributions

# %%
# Kurtosis is a measure of how many outliers you have in your distribution
# - leptokurtic - less tails, less outliers
# - mesokurtic - a normal distribution
# - platykurtic - fat tails, more outliers
